# %%
---
title: "Homework 1, DSAN 6600"
date: 'Sept. 22, 2023'
author:
  - name: Kumar H 
    corresponding: false
    email: hk939@georgetown.edu
format:  
  html:
     mathjax: true
project:
  type: website
  output-dir: docs
---

# %%
import pandas as pd
import numpy as np
import missingno as msno
import os

# %%
os.chdir(r'D:\Work\Georgetown\acad\sem3\viz\tutorial_msno')
# Load your dataset
df = pd.read_csv('dc_tax_data.csv')

# %% [markdown]
# ### Visualize matrix of missing values
#
#
# The following code helps us visualize the missing values in a matrix

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>
